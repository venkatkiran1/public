# %% [markdown]
#                                 LAB SHEET 2 (DS)
#     K VENKAT KIRAN
#     AM.EN.U4CSE20035

# %% [markdown]
# Q1

# %%
import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("company_sales_data.csv")

# %%
profitList = df ['total_profit'].tolist()
monthList  = df ['month_number'].tolist()
faceCremSalesData   = df ['facecream'].tolist()
faceWashSalesData   = df ['facewash'].tolist()
toothPasteSalesData = df ['toothpaste'].tolist()
bathingsoapSalesData   = df ['bathingsoap'].tolist()
shampooSalesData   = df ['shampoo'].tolist()
moisturizerSalesData = df ['moisturizer'].tolist()
totalunits = df ['total_units'].tolist()

plt.plot(monthList, profitList)
plt.xlabel('Month number')
plt.ylabel('Total Profit')
plt.show()

# %% [markdown]
# Q2.1

# %%
plt.plot(monthList, profitList, color='r', linestyle='--')
      
plt.xlabel('Month number')
plt.ylabel('Total Profit')
plt.show()

# %% [markdown]
# Q2.2

# %%
plt.plot(monthList, profitList, color='r', linestyle='--',label="Profit List"  )
      
plt.legend(loc='lower left')
plt.xlabel('Month number')
plt.ylabel('Total Profit')
plt.show()

# %% [markdown]
# Q2.3

# %%
plt.plot(monthList, profitList, color='r', linestyle='--')
plt.xlabel('Month number')
plt.show()

# %% [markdown]
# Q2.4

# %%
plt.plot(monthList, totalunits, color='r', linestyle='--')
plt.ylabel('Sold units number')
plt.show()

# %% [markdown]
# Q2.5

# %%
plt.plot(monthList, totalunits, color='r', linestyle='--',marker='o')
plt.show()

# %% [markdown]
# Q2.6

# %%
plt.plot(monthList, totalunits, color='r', linestyle='--',marker='o',markerfacecolor='r')
plt.show()

# %% [markdown]
# Q2.7

# %%
plt.plot(monthList, totalunits, color='r',  linestyle='--', marker='o', markerfacecolor='r',linewidth=3)
plt.show()

# %% [markdown]
# Q3

# %%
plt.plot(monthList, faceCremSalesData, marker='o', linewidth=3)
plt.plot(monthList, faceWashSalesData,  marker='o', linewidth=3)
plt.plot(monthList, toothPasteSalesData, marker='o', linewidth=3)
plt.plot(monthList, bathingsoapSalesData, marker='o', linewidth=3)
plt.plot(monthList, shampooSalesData, marker='o', linewidth=3)
plt.plot(monthList, moisturizerSalesData, marker='o', linewidth=3)
plt.plot(monthList, totalunits, marker='o', linewidth=3)


plt.show()

# %% [markdown]
# Q4

# %%
plt.scatter(monthList, toothPasteSalesData)
plt.grid(True, linewidth= 1, linestyle="--")
plt.show()

# %% [markdown]
# Q5

# %%
plt.bar([a-0.25 for a in monthList], faceCremSalesData)
plt.bar([a+0.25 for a in monthList], faceWashSalesData)
plt.grid(True, linewidth= 1, linestyle="--")
plt.show()

# %% [markdown]
# Q6

# %%
import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("company_sales_data.csv")
monthList  = df ['month_number'].tolist()
bathingsoapSalesData   = df ['bathingsoap'].tolist()
plt.bar(monthList, bathingsoapSalesData)
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.title(' Sales data')
plt.xticks(monthList)
plt.grid(True, linewidth= 1, linestyle="--")
plt.title('bathingsoap sales data')
plt.savefig('company_sales_data.csv.png', dpi=150)
plt.show()

# %% [markdown]
# Q7

# %%
range = [150000, 175000, 200000, 225000, 250000, 300000, 350000, 400000]
plt.hist(profitList, range, label = 'Profit data')
plt.title("profit Data")
plt.show()
